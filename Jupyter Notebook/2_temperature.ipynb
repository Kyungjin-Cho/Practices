# %% [markdown]
# ## Histogram practices

# %%
import matplotlib.pyplot as plt
import random
import csv

# %%
plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 7, 8, 10])
plt.show()

# %%
print(random.randint(1, 6))
# Out:
# 6

# %%
dice = []
for i in range(5):
    dice.append(random.randint(1, 6))
plt.hist(dice, bins = 6, color = 'hotpink')
plt.show()

# %%
dice = []
for i in range(100):
    dice.append(random.randint(1, 6))
plt.hist(dice, bins = 6, color = 'skyblue')
plt.show()

# %%
dice = []
for i in range(1000000):
    dice.append(random.randint(1, 6))
plt.hist(dice, bins = 6, color = 'purple')
plt.show()

# %% [markdown]
# ## Temperatures in Seoul

# %%
f = open('seoul_temperature.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))

plt.hist(result, bins=100, color='r')
plt.show()

# %%
f = open('seoul_temperature.csv')
data = csv.reader(f)
next(data)
aug = []
for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))

plt.hist(aug, bins=100, color='orange')
plt.show()

# %%
f = open('seoul_temperature.csv')
data = csv.reader(f)
next(data)

aug = []
jan = []

for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

plt.hist(aug, bins=100, color='r', label='Aug')
plt.hist(jan, bins=100, color='b', label='Jan')
plt.legend()
plt.show()

# %%
result = []
for i in range(13):
    result.append(random.randint(1, 1000))
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [26, 102, 206, 238, 273, 359, 422, 467, 477, 614, 623, 757, 892]

# %%
f = open('seoul_temperature.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))

plt.boxplot(result)
plt.show()

# %%
f = open('seoul_temperature.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))
    
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
plt.boxplot([aug, jan])
plt.show()

# %%
f = open('seoul_temperature.csv')
data = csv.reader(f)
next(data)

month = [[], [], [], [], [], [], [], [], [], [], [], []]

for row in data:
    if row[-1] != '':
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.boxplot(month)
plt.show()

# %%
f = open('seoul_temperature.csv')
data = csv.reader(f)
next(data)

day = []
for i in range(31):
    day.append([])
    
for row in data:
    if row[-1] != '':
        if row[0].split('-')[1] == '08':
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))
            
plt.figure(figsize=(10, 5), dpi=300)
plt.boxplot(day, showfliers=False)

plt.show()
